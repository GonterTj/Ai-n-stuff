# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env
import os
import time

# %%
# Saving logs to visulise in Tensorboard, saving models
models_dir = f"models/Mountain-{time.time()}"
logdir = f"logs/Mountain-{time.time()}"
if not os.path.exists(models_dir):
    os.makedirs(models_dir)
if not os.path.exists(logdir):
    os.makedirs(logdir)

# %%
# Parallel environments
env = make_vec_env("MountainCarContinuous-v0", n_envs=1)

# %%
# The learning agent and hyperparameters
model = PPO(
    policy=MlpPolicy,
    env=env,
    seed=0,
    batch_size=256,
    ent_coef=0.00429,
    learning_rate=7.77e-05,
    n_epochs=10,
    n_steps=8,
    gae_lambda=0.9,
    gamma=0.9999,
    clip_range=0.1,
    max_grad_norm =5,
    vf_coef=0.19,
    use_sde=True,
    policy_kwargs=dict(log_std_init=-3.29, ortho_init=False),
    verbose=1,
    tensorboard_log=logdir
    )
# Out:
# Using cuda device
# c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\ppo\ppo.py:145: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 8`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 8
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=8 and n_envs=1)
#   warnings.warn(

# %%
#Training and saving models along the way
TIMESTEPS = 20000
for i in range(10): 
    model.learn(total_timesteps=TIMESTEPS,reset_num_timesteps=False, tb_log_name="PPO")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Logging to logs/Mountain-1678440309.5037627\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -59.6    |
# | time/              |          |
# |    fps             | 381      |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 116920   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 2          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 116928     |
# | train/                  |            |
# |    approx_kl            | 0.01514975 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.4        |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.0361     |
# |    n_updates            | 146130     |
# |    policy_gradient_loss | 0.00969    |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00618    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 3          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 116936     |
# | train/                  |            |
# |    approx_kl            | 0.01625076 |
# |    clip_fraction        | 0.9        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.4        |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.0477     |
# |    n_updates            | 146140     |
# |    policy_gradient_loss | 0.0434     |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00668    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 4           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 116944      |
# | train/                  |             |
# |    approx_kl            | 0.011133984 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.4         |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0261      |
# |    n_updates            | 146150      |
# |    policy_gradient_loss | 0.00348     |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00804     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -59.6         |
# | time/                   |               |
# |    fps                  | 93            |
# |    iterations           | 5             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 116952        |
# | train/                  |               |
# |    approx_kl            | 2.5331974e-07 |
# |    clip_fraction        | 0.1           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 2.4           |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.011         |
# |    n_updates            | 146160        |
# |    policy_gradient_loss | 0.00281       |
# |    std                  | 0.0604        |
# |    value_loss           | 0.00646       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 6           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 116960      |
# | train/                  |             |
# |    approx_kl            | 0.022178553 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.4         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0498      |
# |    n_updates            | 146170      |
# |    policy_gradient_loss | 0.0145      |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00519     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 7            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 116968       |
# | train/                  |              |
# |    approx_kl            | 3.618002e-05 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.4          |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0109       |
# |    n_updates            | 146180       |
# |    policy_gradient_loss | 0.00633      |
# |    std                  | 0.0604       |
# |    value_loss           | 0.00586      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 8           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 116976      |
# | train/                  |             |
# |    approx_kl            | 0.030588388 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.4         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0616      |
# |    n_updates            | 146190      |
# |    policy_gradient_loss | 0.016       |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00599     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 9          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 116984     |
# | train/                  |            |
# |    approx_kl            | 0.53811175 |
# |    clip_fraction        | 0.8        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.4        |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.539      |
# |    n_updates            | 146200     |
# |    policy_gradient_loss | 0.186      |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00744    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 10          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 116992      |
# | train/                  |             |
# |    approx_kl            | 0.036123678 |
# |    clip_fraction        | 0.7         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.4         |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0684      |
# |    n_updates            | 146210      |
# |    policy_gradient_loss | 0.0642      |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00843     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 999       |
# |    ep_rew_mean          | -59.6     |
# | time/                   |           |
# |    fps                  | 85        |
# |    iterations           | 11        |
# |    time_elapsed         | 1         |
# |    total_timesteps      | 117000    |
# | train/                  |           |
# |    approx_kl            | 53.825165 |
# |    clip_fraction        | 0.9       |
# |    clip_range           | 0.1       |
# |    entropy_loss         | 2.41      |
# |    explained_variance   | 0         |
# |    learning_rate        | 7.77e-05  |
# |    loss                 | 23.2      |
# |    n_updates            | 146220    |
# |    policy_gradient_loss | 11.5      |
# |    std                  | 0.0604    |
# |    value_loss           | 0.00774   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 12          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 117008      |
# | train/                  |             |
# |    approx_kl            | 0.008028425 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.017       |
# |    n_updates            | 146230      |
# |    policy_gradient_loss | 0.00942     |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00821     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -59.6         |
# | time/                   |               |
# |    fps                  | 85            |
# |    iterations           | 13            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 117016        |
# | train/                  |               |
# |    approx_kl            | 1.6018748e-05 |
# |    clip_fraction        | 0.8           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 2.4           |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.0119        |
# |    n_updates            | 146240        |
# |    policy_gradient_loss | 0.198         |
# |    std                  | 0.0604        |
# |    value_loss           | 0.00854       |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 85         |
# |    iterations           | 14         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 117024     |
# | train/                  |            |
# |    approx_kl            | 0.22983772 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.4        |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.187      |
# |    n_updates            | 146250     |
# |    policy_gradient_loss | 0.0549     |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00767    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 15          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 117032      |
# | train/                  |             |
# |    approx_kl            | 0.029375777 |
# |    clip_fraction        | 0.9         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.077       |
# |    n_updates            | 146260      |
# |    policy_gradient_loss | 0.116       |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00759     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 999       |
# |    ep_rew_mean          | -59.6     |
# | time/                   |           |
# |    fps                  | 85        |
# |    iterations           | 16        |
# |    time_elapsed         | 1         |
# |    total_timesteps      | 117040    |
# | train/                  |           |
# |    approx_kl            | 0.9217478 |
# |    clip_fraction        | 0.8       |
# |    clip_range           | 0.1       |
# |    entropy_loss         | 2.41      |
# |    explained_variance   | 0         |
# |    learning_rate        | 7.77e-05  |
# |    loss                 | 0.305     |
# |    n_updates            | 146270    |
# |    policy_gradient_loss | 0.185     |
# |    std                  | 0.0604    |
# |    value_loss           | 0.00751   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 85         |
# |    iterations           | 17         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 117048     |
# | train/                  |            |
# |    approx_kl            | 0.01563634 |
# |    clip_fraction        | 0.9        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.0469     |
# |    n_updates            | 146280     |
# |    policy_gradient_loss | 0.0743     |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00818    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 18           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 117056       |
# | train/                  |              |
# |    approx_kl            | 0.0073067993 |
# |    clip_fraction        | 0.5          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0174       |
# |    n_updates            | 146290       |
# |    policy_gradient_loss | 0.0176       |
# |    std                  | 0.0604       |
# |    value_loss           | 0.0077       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -59.6         |
# | time/                   |               |
# |    fps                  | 84            |
# |    iterations           | 19            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 117064        |
# | train/                  |               |
# |    approx_kl            | 0.00068962574 |
# |    clip_fraction        | 0.6           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 2.41          |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.0112        |
# |    n_updates            | 146300        |
# |    policy_gradient_loss | 0.0599        |
# |    std                  | 0.0604        |
# |    value_loss           | 0.00629       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 20          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 117072      |
# | train/                  |             |
# |    approx_kl            | 0.048072174 |
# |    clip_fraction        | 0.9         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0823      |
# |    n_updates            | 146310      |
# |    policy_gradient_loss | 0.236       |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00742     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 84         |
# |    iterations           | 21         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 117080     |
# | train/                  |            |
# |    approx_kl            | 0.04012859 |
# |    clip_fraction        | 0.9        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.095      |
# |    n_updates            | 146320     |
# |    policy_gradient_loss | 0.285      |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00857    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 22          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 117088      |
# | train/                  |             |
# |    approx_kl            | 0.009033576 |
# |    clip_fraction        | 0.9         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0285      |
# |    n_updates            | 146330      |
# |    policy_gradient_loss | 0.302       |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00878     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 23          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 117096      |
# | train/                  |             |
# |    approx_kl            | 0.019137599 |
# |    clip_fraction        | 0.8         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0485      |
# |    n_updates            | 146340      |
# |    policy_gradient_loss | 0.175       |
# |    std                  | 0.0604      |
# |    value_loss           | 0.00891     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 24         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 117104     |
# | train/                  |            |
# |    approx_kl            | 0.29881778 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.204      |
# |    n_updates            | 146350     |
# |    policy_gradient_loss | 0.0319     |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00877    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 25         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 117112     |
# | train/                  |            |
# |    approx_kl            | 0.12374005 |
# |    clip_fraction        | 0.9        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.142      |
# |    n_updates            | 146360     |
# |    policy_gradient_loss | 0.112      |
# |    std                  | 0.0604     |
# |    value_loss           | 0.00837    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 26         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 117120     |
# | train/                  |            |
# |    approx_kl            | 0.39291275 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.225      |
# |    n_updates            | 146370     |
# |    policy_gradient_loss | 0.109      |
# |    std                  | 0.0605     |
# |    value_loss           | 0.00876    |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -59.6         |
# | time/                   |               |
# |    fps                  | 83            |
# |    iterations           | 27            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 117128        |
# | train/                  |               |
# |    approx_kl            | 0.00010243058 |
# |    clip_fraction        | 0.5           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 2.41          |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.0102        |
# |    n_updates            | 146380        |
# |    policy_gradient_loss | 0.115         |
# |    std                  | 0.0605        |
# |    value_loss           | 0.0089        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 28           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 117136       |
# | train/                  |              |
# |    approx_kl            | 0.0008932501 |
# |    clip_fraction        | 0.5          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0149       |
# |    n_updates            | 146390       |
# |    policy_gradient_loss | 0.0426       |
# |    std                  | 0.0605       |
# |    value_loss           | 0.00889      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 29         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 117144     |
# | train/                  |            |
# |    approx_kl            | 0.06361796 |
# |    clip_fraction        | 0.9        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.101      |
# |    n_updates            | 146400     |
# |    policy_gradient_loss | 0.111      |
# |    std                  | 0.0605     |
# |    value_loss           | 0.00804    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 30         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 117152     |
# | train/                  |            |
# |    approx_kl            | 0.41782033 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.235      |
# |    n_updates            | 146410     |
# |    policy_gradient_loss | 0.0487     |
# |    std                  | 0.0605     |
# |    value_loss           | 0.00846    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 31         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 117160     |
# | train/                  |            |
# |    approx_kl            | 0.03647069 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.0705     |
# |    n_updates            | 146420     |
# |    policy_gradient_loss | 0.0188     |
# |    std                  | 0.0605     |
# |    value_loss           | 0.00713    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 999       |
# |    ep_rew_mean          | -59.6     |
# | time/                   |           |
# |    fps                  | 83        |
# |    iterations           | 32        |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 117168    |
# | train/                  |           |
# |    approx_kl            | 0.6306684 |
# |    clip_fraction        | 0.487     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | 2.41      |
# |    explained_variance   | 0         |
# |    learning_rate        | 7.77e-05  |
# |    loss                 | 0.27      |
# |    n_updates            | 146430    |
# |    policy_gradient_loss | 0.0604    |
# |    std                  | 0.0605    |
# |    value_loss           | 0.00741   |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -59.6         |
# | time/                   |               |
# |    fps                  | 83            |
# |    iterations           | 33            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 117176        |
# | train/                  |               |
# |    approx_kl            | 3.7819147e-05 |
# |    clip_fraction        | 0.6           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 2.41          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.0124        |
# |    n_updates            | 146440        |
# |    policy_gradient_loss | 0.0554        |
# |    std                  | 0.0605        |
# |    value_loss           | 0.00793       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 34          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 117184      |
# | train/                  |             |
# |    approx_kl            | 0.030082144 |
# |    clip_fraction        | 0.9         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0625      |
# |    n_updates            | 146450      |
# |    policy_gradient_loss | 0.126       |
# |    std                  | 0.0605      |
# |    value_loss           | 0.00775     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 35         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 117192     |
# | train/                  |            |
# |    approx_kl            | 0.13617358 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.156      |
# |    n_updates            | 146460     |
# |    policy_gradient_loss | 0.057      |
# |    std                  | 0.0605     |
# |    value_loss           | 0.00843    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 36          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 117200      |
# | train/                  |             |
# |    approx_kl            | 0.011233687 |
# |    clip_fraction        | 0.7         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0341      |
# |    n_updates            | 146470      |
# |    policy_gradient_loss | 0.0213      |
# |    std                  | 0.0605      |
# |    value_loss           | 0.00717     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 37         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 117208     |
# | train/                  |            |
# |    approx_kl            | 0.08864544 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.159      |
# |    n_updates            | 146480     |
# |    policy_gradient_loss | 0.0667     |
# |    std                  | 0.0605     |
# |    value_loss           | 0.0081     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 38         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 117216     |
# | train/                  |            |
# |    approx_kl            | 0.04773152 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0          |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.0834     |
# |    n_updates            | 146490     |
# |    policy_gradient_loss | 0.0466     |
# |    std                  | 0.0605     |
# |    value_loss           | 0.00714    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 39           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 117224       |
# | train/                  |              |
# |    approx_kl            | 7.003546e-07 |
# |    clip_fraction        | 0.5          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0113       |
# |    n_updates            | 146500       |
# |    policy_gradient_loss | 0.0157       |
# |    std                  | 0.0605       |
# |    value_loss           | 0.00724      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 40          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 117232      |
# | train/                  |             |
# |    approx_kl            | 0.008591488 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0259      |
# |    n_updates            | 146510      |
# |    policy_gradient_loss | 0.0122      |
# |    std                  | 0.0605      |
# |    value_loss           | 0.00643     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 41          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 117240      |
# | train/                  |             |
# |    approx_kl            | 0.048454836 |
# |    clip_fraction        | 0.9         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0841      |
# |    n_updates            | 146520      |
# |    policy_gradient_loss | 0.119       |
# |    std                  | 0.0605      |
# |    value_loss           | 0.00655     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 42          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 117248      |
# | train/                  |             |
# |    approx_kl            | 0.010395847 |
# |    clip_fraction        | 0.9         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0266      |
# |    n_updates            | 146530      |
# |    policy_gradient_loss | 1.01        |
# |    std                  | 0.0605      |
# |    value_loss           | 0.00797     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 43           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 117256       |
# | train/                  |              |
# |    approx_kl            | 0.0025162846 |
# |    clip_fraction        | 0.463        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0107       |
# |    n_updates            | 146540       |
# |    policy_gradient_loss | 0.0436       |
# |    std                  | 0.0605       |
# |    value_loss           | 0.00852      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 44           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 117264       |
# | train/                  |              |
# |    approx_kl            | 0.0002848953 |
# |    clip_fraction        | 0.5          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.011        |
# |    n_updates            | 146550       |
# |    policy_gradient_loss | 0.0159       |
# |    std                  | 0.0605       |
# |    value_loss           | 0.00731      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 45           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 117272       |
# | train/                  |              |
# |    approx_kl            | 0.0075055584 |
# |    clip_fraction        | 0.5          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0175       |
# |    n_updates            | 146560       |
# |    policy_gradient_loss | 0.0365       |
# |    std                  | 0.0605       |
# |    value_loss           | 0.006        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 46           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 117280       |
# | train/                  |              |
# |    approx_kl            | 0.0014702827 |
# |    clip_fraction        | 0.3          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.011        |
# |    n_updates            | 146570       |
# |    policy_gradient_loss | 0.00836      |
# |    std                  | 0.0605       |
# |    value_loss           | 0.00601      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 47           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 117288       |
# | train/                  |              |
# |    approx_kl            | 0.0014892891 |
# |    clip_fraction        | 0.45         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0107       |
# |    n_updates            | 146580       |
# |    policy_gradient_loss | 0.0508       |
# |    std                  | 0.0605       |
# |    value_loss           | 0.00588      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 999       |
# |    ep_rew_mean          | -59.6     |
# | time/                   |           |
# |    fps                  | 83        |
# |    iterations           | 48        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 117296    |
# | train/                  |           |
# |    approx_kl            | 0.6781393 |
# |    clip_fraction        | 0.8       |
# |    clip_range           | 0.1       |
# |    entropy_loss         | 2.41      |
# |    explained_variance   | 0         |
# |    learning_rate        | 7.77e-05  |
# |    loss                 | 0.279     |
# |    n_updates            | 146590    |
# |    policy_gradient_loss | 0.0921    |
# |    std                  | 0.0605    |
# |    value_loss           | 0.0064    |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.6        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 49           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 117304       |
# | train/                  |              |
# |    approx_kl            | 0.0019100606 |
# |    clip_fraction        | 0.8          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0104       |
# |    n_updates            | 146600       |
# |    policy_gradient_loss | 0.124        |
# |    std                  | 0.0605       |
# |    value_loss           | 0.0077       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 50         |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 117312     |
# | train/                  |            |
# |    approx_kl            | 0.07026654 |
# |    clip_fraction        | 0.9        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.105      |
# |    n_updates            | 146610     |
# |    policy_gradient_loss | 0.207      |
# |    std                  | 0.0605     |
# |    value_loss           | 0.00802    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 999      |
# |    ep_rew_mean          | -59.6    |
# | time/                   |          |
# |    fps                  | 83       |
# |    iterations           | 51       |
# |    time_elapsed         | 4        |
# |    total_timesteps      | 117320   |
# | train/                  |          |
# |    approx_kl            | 0.813323 |
# |    clip_fraction        | 0.9      |
# |    clip_range           | 0.1      |
# |    entropy_loss         | 2.41     |
# |    explained_variance   | 0        |
# |    learning_rate        | 7.77e-05 |
# |    loss                 | 0.296    |
# |    n_updates            | 146620   |
# |    policy_gradient_loss | 0.101    |
# |    std                  | 0.0605   |
# |    value_loss           | 0.00809  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 52          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 117328      |
# | train/                  |             |
# |    approx_kl            | 0.028162688 |
# |    clip_fraction        | 0.7         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.41        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0767      |
# |    n_updates            | 146630      |
# |    policy_gradient_loss | 0.0836      |
# |    std                  | 0.0606      |
# |    value_loss           | 0.00847     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 999       |
# |    ep_rew_mean          | -59.6     |
# | time/                   |           |
# |    fps                  | 82        |
# |    iterations           | 53        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 117336    |
# | train/                  |           |
# |    approx_kl            | 0.2878764 |
# |    clip_fraction        | 0.8       |
# |    clip_range           | 0.1       |
# |    entropy_loss         | 2.41      |
# |    explained_variance   | 0         |
# |    learning_rate        | 7.77e-05  |
# ...
# |    value_loss           | 0.00646     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -53.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 956         |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 124560      |
# | train/                  |             |
# |    approx_kl            | 0.015889436 |
# |    clip_fraction        | 0.8         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.45        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0475      |
# |    n_updates            | 155670      |
# |    policy_gradient_loss | 0.0829      |
# |    std                  | 0.0635      |
# |    value_loss           | 0.00634     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -52.2         |
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 957           |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 124568        |
# | train/                  |               |
# |    approx_kl            | 0.00023372471 |
# |    clip_fraction        | 0.4           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 2.45          |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.0112        |
# |    n_updates            | 155680        |
# |    policy_gradient_loss | 0.0144        |
# |    std                  | 0.0635        |
# |    value_loss           | 0.00578       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -52.2         |
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 958           |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 124576        |
# | train/                  |               |
# |    approx_kl            | 0.00014282018 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 0.897         |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.0161        |
# |    n_updates            | 155690        |
# |    policy_gradient_loss | -0.00841      |
# |    std                  | 0.0636        |
# |    value_loss           | 0.073         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 959         |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 124584      |
# | train/                  |             |
# |    approx_kl            | 0.020083651 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.49        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | -0.0252     |
# |    n_updates            | 155700      |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.0635      |
# |    value_loss           | 0.0828      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -52.2         |
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 960           |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 124592        |
# | train/                  |               |
# |    approx_kl            | 2.8692186e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 0.719         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00833       |
# |    n_updates            | 155710        |
# |    policy_gradient_loss | -0.000511     |
# |    std                  | 0.0635        |
# |    value_loss           | 0.0675        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 961         |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 124600      |
# | train/                  |             |
# |    approx_kl            | 0.020736314 |
# |    clip_fraction        | 0.588       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.7         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | -0.0443     |
# |    n_updates            | 155720      |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 0.0635      |
# |    value_loss           | 0.0383      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 962          |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 124608       |
# | train/                  |              |
# |    approx_kl            | 0.0026922524 |
# |    clip_fraction        | 0.325        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.17         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.0175      |
# |    n_updates            | 155730       |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 0.0634       |
# |    value_loss           | 0.0737       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -52.2      |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 963        |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 124616     |
# | train/                  |            |
# |    approx_kl            | 0.75311184 |
# |    clip_fraction        | 0.85       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 1.92       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | -0.0494    |
# |    n_updates            | 155740     |
# |    policy_gradient_loss | -0.0544    |
# |    std                  | 0.0634     |
# |    value_loss           | 0.0534     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 964         |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 124624      |
# | train/                  |             |
# |    approx_kl            | 0.033078924 |
# |    clip_fraction        | 0.525       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.76        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.162       |
# |    n_updates            | 155750      |
# |    policy_gradient_loss | 0.115       |
# |    std                  | 0.0635      |
# |    value_loss           | 0.065       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 999       |
# |    ep_rew_mean          | -52.2     |
# | time/                   |           |
# |    fps                  | 81        |
# |    iterations           | 965       |
# |    time_elapsed         | 94        |
# |    total_timesteps      | 124632    |
# | train/                  |           |
# |    approx_kl            | 0.4247045 |
# |    clip_fraction        | 0.863     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | 2.26      |
# |    explained_variance   | 0         |
# |    learning_rate        | 7.77e-05  |
# |    loss                 | 0.256     |
# |    n_updates            | 155760    |
# |    policy_gradient_loss | 0.197     |
# |    std                  | 0.0635    |
# |    value_loss           | 0.0628    |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 966          |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 124640       |
# | train/                  |              |
# |    approx_kl            | 0.0031040832 |
# |    clip_fraction        | 0.613        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.39         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00318      |
# |    n_updates            | 155770       |
# |    policy_gradient_loss | 0.021        |
# |    std                  | 0.0635       |
# |    value_loss           | 0.000886     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 999           |
# |    ep_rew_mean          | -52.2         |
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 967           |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 124648        |
# | train/                  |               |
# |    approx_kl            | 0.00036367774 |
# |    clip_fraction        | 0.8           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 2.46          |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00719       |
# |    n_updates            | 155780        |
# |    policy_gradient_loss | 0.155         |
# |    std                  | 0.0635        |
# |    value_loss           | 0.00562       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 968         |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 124656      |
# | train/                  |             |
# |    approx_kl            | 0.065455586 |
# |    clip_fraction        | 0.8         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.45        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.168       |
# |    n_updates            | 155790      |
# |    policy_gradient_loss | 0.14        |
# |    std                  | 0.0635      |
# |    value_loss           | 0.00745     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 969          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 124664       |
# | train/                  |              |
# |    approx_kl            | 0.0048721284 |
# |    clip_fraction        | 0.9          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.46         |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0122       |
# |    n_updates            | 155800       |
# |    policy_gradient_loss | 0.118        |
# |    std                  | 0.0635       |
# |    value_loss           | 0.00762      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 970          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 124672       |
# | train/                  |              |
# |    approx_kl            | 6.912649e-05 |
# |    clip_fraction        | 0.4          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.46         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0113       |
# |    n_updates            | 155810       |
# |    policy_gradient_loss | 0.0271       |
# |    std                  | 0.0635       |
# |    value_loss           | 0.00623      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -52.2      |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 971        |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 124680     |
# | train/                  |            |
# |    approx_kl            | 0.18056239 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 2.46       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 7.77e-05   |
# |    loss                 | 0.165      |
# |    n_updates            | 155820     |
# |    policy_gradient_loss | 0.0246     |
# |    std                  | 0.0635     |
# |    value_loss           | 0.00595    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 972         |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 124688      |
# | train/                  |             |
# |    approx_kl            | 0.002157122 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.46        |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0131      |
# |    n_updates            | 155830      |
# |    policy_gradient_loss | 0.05        |
# |    std                  | 0.0635      |
# |    value_loss           | 0.00667     |
# -----------------------------------------

# %%
# Check model performance
# load the best model you observed from tensorboard - the one reach the goal/ obtaining highest return
models_dir = "models/Mountain-1653282767.3143597"
model_path = f"{models_dir}/80000"
best_model = PPO.load(model_path, env=env)
obs = env.reset()
while True:
    action, _states = best_model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()  #use Python IDE to check, I havn't figure out how to render in Notebook
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       3 models_dir = "models/Mountain-1653282767.3143597"
#       4 model_path = f"{models_dir}/80000"
# ----> 5 best_model = PPO.load(model_path, env=env)
#       6 obs = env.reset()
#       7 while True:
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\base_class.py:659, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     656     print("== CURRENT SYSTEM INFO ==")
#     657     get_system_info()
# --> 659 data, params, pytorch_variables = load_from_zip_file(
#     660     path,
#     661     device=device,
#     662     custom_objects=custom_objects,
#     663     print_system_info=print_system_info,
#     664 )
#     666 # Remove stored device information and replace with ours
#     667 if "policy_kwargs" in data:
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\save_util.py:390, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     363 def load_from_zip_file(
#     364     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     365     load_data: bool = True,
#    (...)
#     369     print_system_info: bool = False,
#     370 ) -> (Tuple[Optional[Dict[str, Any]], Optional[TensorDict], Optional[TensorDict]]):
#     371     """
#     372     Load model data from a .zip archive
#     373
#    (...)
#     388         and dict of pytorch variables
#     389     """
# --> 390     load_path = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     392     # set device to cpu if cuda is not available
#     393     device = get_device(device=device)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\save_util.py:234, in open_path_str(path, mode, verbose, suffix)
#     219 @open_path.register(str)
#     220 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     221     """
#     222     Open a path given by a string. If writing to the path, the function ensures
#     223     that the path exists.
#    (...)
#     232     :return:
#     233     """
# --> 234     return open_path(pathlib.Path(path), mode, verbose, suffix)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\save_util.py:286, in open_path_pathlib(path, mode, verbose, suffix)
#     279         path.parent.mkdir(exist_ok=True, parents=True)
#     281 # if opening was successful uses the identity function
#     282 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     283 #   with corrections
#     284 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 286 return open_path(path, mode, verbose, suffix)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\save_util.py:266, in open_path_pathlib(path, mode, verbose, suffix)
#     264             path, suffix = newpath, None
#     265         else:
# --> 266             raise error
#     267 else:
#     268     try:
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\save_util.py:258, in open_path_pathlib(path, mode, verbose, suffix)
#     256 if mode == "r":
#     257     try:
# --> 258         path = path.open("rb")
#     259     except FileNotFoundError as error:
#     260         if suffix is not None and suffix != "":
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models\\Mountain-1653282767.3143597\\80000.zip'
